# %%
print('Good morning!')
# Out:
# Good morning!

# %%
print("This is a very long line\nbut we can break it up\nusing newline characters.")
# Out:
# This is a very long line
# but we can break it up
# using newline characters.

# %%
print("""this is a triple quoted string""")
# Out:
# this is a triple quoted string

# %%
print("""this is also a very long line
      that we can break up
      using triple quotes.""" )
# Out:
# this is also a very long line
#       that we can break up
#       using triple quotes.

# %%
my_var = 'barks'
print('A Dog ' + my_var +'!')
# Out:
# A Dog barks!

# %%
print(f'A dog {my_var}!')
# Out:
# A dog barks!

# %%
a=10
print(f'The value of a is {a}')
# Out:
# The value of a is 10

# %%
num_1=10
num_2=20
num_3=num_1
num_1=100
print('num_3:', num_3)
# Out:
# num_3: 10

# %%
num_x="2"
print(num_x)
# Out:
# 2

# %%
print(13//5)
# Out:
# 2

# %%
a=True
b=True

print(not b)
# Out:
# False
